# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelBernardinoDev/DataScience/blob/main/dataViz_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Análise de Vendas nas Lojas A, B, C e D
#
# Este projeto gera visualizações das vendas mensais das lojas **A, B, C e D** ao longo do ano de 2022, utilizando **Matplotlib** para criar gráficos comparativos.
#
# ## 📝 Descrição
#
# O código cria uma **figura com 4 subplots** (2x2), onde cada gráfico representa a evolução das vendas de uma loja ao longo do tempo.
# Algumas melhorias foram implementadas para uma melhor visualização dos dados:
# - Ajuste de espaçamentos entre os subplots (`wspace` e `hspace`).
# - Remoção de bordas superiores e direitas para um design mais limpo.
# - Personalização da grade (`grid`) para facilitar a leitura dos gráficos.
# - Formatação do eixo X para exibir os meses corretamente.
# - Aplicação de legenda para cada gráfico.
#
# ## 📌 Pré-requisitos
#
# Antes de rodar o código, instale as bibliotecas necessárias:
#
# ```bash
# pip install matplotlib pandas

# %% [markdown]
# ## Set dos dados para  análise

# %%
import pandas as pd
import matplotlib.pyplot as plt

lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# Criando DataFrame
df = pd.DataFrame(vendas_2022, index=lojas)

# %%
df.head()
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %% [markdown]
# ## Criando gráfico com subplots 2x2.

# %%
import matplotlib.pyplot as plt

cores = ['darkviolet', 'green', 'darkblue', 'coral']

fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar os espaçamentos entre os subplots
plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Adicionando um título geral
fig.suptitle('Vendas no período de janeiro a dezembro de 2022 nas lojas A, B, C e D', fontsize=16)

#Loop para plotar e customizar os subplots
for i, ax in enumerate(axs.flat):
    ax.plot(df.loc[df.index[i]], color=cores[i], lw=3)
    ax.set_title(f'Vendas na loja {df.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mês', fontsize=14)
    ax.set_ylabel('Número de vendas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')

    # Ajustando o Y
    ax.set_ylim(50, 400)
    ax.yaxis.set_tick_params(labelsize=12)
    ax.xaxis.set_tick_params(labelsize=12)

    # Estética
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(True, linestyle="--", alpha=0.6)

plt.show()
